# %% [markdown]
# # Performance Results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# df1 = pd.read_csv('/Users/vp/Downloads/0.csv')
# df2 = pd.read_csv('/Users/vp/Downloads/1.csv')
# df3 = pd.read_csv('/Users/vp/Downloads/2.csv')
# df4 = pd.read_csv('/Users/vp/Downloads/3.csv')
# df5 = pd.read_csv('/Users/vp/Downloads/4.csv')
# df6 = pd.read_csv('/Users/vp/Downloads/5.csv')
# df7 = pd.read_csv('/Users/vp/Downloads/6.csv')
# df8 = pd.read_csv('/Users/vp/Downloads/7.csv')

# concat_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8], ignore_index=True).reset_index(drop=True)
# concat_df['Cores & Instances'] = concat_df['Cores & Instances'].replace('2 cores & 24 instances', '2 cores & 24 instances - 4W')
# concat_df.to_csv('2-cores-24-instances-4w.csv')

# %%
# Read in the CSV files
df1 = pd.read_csv("/Users/vp/Desktop/MDSE/2S/EGD/project/EGD_Project/performance-csv/2-cores-6-instances.csv")
df2 = pd.read_csv("/Users/vp/Desktop/MDSE/2S/EGD/project/EGD_Project/performance-csv/2-cores-12-instances.csv")
df3 = pd.read_csv("/Users/vp/Desktop/MDSE/2S/EGD/project/EGD_Project/performance-csv/2-cores-18-instances.csv")
df4 = pd.read_csv('/Users/vp/Desktop/MDSE/2S/EGD/project/EGD_Project/performance-csv/2-cores-6-instances-4w.csv')
df5 = pd.read_csv('/Users/vp/Desktop/MDSE/2S/EGD/project/EGD_Project/performance-csv/2-cores-12-instances-4w.csv')
df6 = pd.read_csv('/Users/vp/Desktop/MDSE/2S/EGD/project/EGD_Project/performance-csv/2-cores-24-instances.csv')
df7 = pd.read_csv('/Users/vp/Desktop/MDSE/2S/EGD/project/EGD_Project/performance-csv/2-cores-18-instances-4w.csv')
df8 = pd.read_csv('/Users/vp/Desktop/MDSE/2S/EGD/project/EGD_Project/performance-csv/2-cores-24-instances-4w.csv')
df4 = df4.drop('Unnamed: 0', axis=1)
df5 = df5.drop('Unnamed: 0', axis=1)
# Concatenate the dataframes
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8], ignore_index=True)
df['Query/Model'] = df['Query/Model'].replace('Liner Regression', 'Linear Regression')
df['Cores & Instances'] = df['Cores & Instances'].replace('2 cores & 18 instances', '2 cores & 18 instances - 2W')

# %%
# fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(40, 15))
# data1 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 100)].reset_index(drop=True)
# data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
# data2 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 700)].reset_index(drop=True)
# data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
# data3 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 1300)].reset_index(drop=True)
# data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# # Column 1
# axs[0, 0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
# axs[0, 0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
# axs[0, 0].set_xticks([])
# axs[0, 0].set_title(r'$\bf{2\ cores\ and\ 6\ instances\ -\ 2\ workers}$' +'\n\nDataset size: 100 MB',fontsize=15)
# axs[0, 0].legend()
# # Column 2
# axs[1, 0].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
# axs[1, 0].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
# axs[1, 0].set_xticks([])
# axs[1, 0].set_title('\nDataset size: 700 MB', fontsize=15)
# axs[1, 0].legend()
# # Coumn 3
# axs[2, 0].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
# axs[2, 0].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
# axs[2, 0].set_xticks(range(len(data3)))
# axs[2, 0].set_xticklabels(data3['Query/Model'].values, rotation=45)
# axs[2, 0].legend()

# data1 = df[(df['Cores & Instances'] == '2 cores & 6 instances - 4W') & (df['Dataset size'] == 100)].reset_index(drop=True)
# data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
# data2 = df[(df['Cores & Instances'] == '2 cores & 6 instances - 4W') & (df['Dataset size'] == 700)].reset_index(drop=True)
# data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
# data3 = df[(df['Cores & Instances'] == '2 cores & 6 instances - 4W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
# data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# # Column 1
# axs[0, 1].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
# axs[0, 1].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
# axs[0, 1].set_xticks([])
# axs[0, 1].set_title(r'$\bf{2\ cores\ and\ 6\ instances\ -\ 4\ workers}$' +'\n\nDataset size: 100 MB',fontsize=15)
# axs[0, 1].legend()
# # Column 2
# axs[1, 1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
# axs[1, 1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
# axs[1, 1].set_xticks([])
# axs[1, 1].set_title('\nDataset size: 700 MB', fontsize=15)
# axs[1, 1].legend()
# # Coumn 3
# axs[2, 1].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
# axs[2, 1].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
# axs[2, 1].set_xticks(range(len(data3)))
# axs[2, 1].set_xticklabels(data3['Query/Model'].values, rotation=45)
# axs[2, 1].legend()

# %% [markdown]
# ## All results

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(40, 15))
# 2 cores & 6 instances - 2W
data1 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0, 0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0, 0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0, 0].set_xticks([])
axs[0, 0].set_title(r'$\bf{2\ workers}$' +'\n\nDataset size: 100 MB',fontsize=15)
axs[0, 0].legend()
# Column 2
axs[1, 0].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1, 0].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1, 0].set_xticks([])
axs[1, 0].set_title('\nDataset size: 700 MB', fontsize=15)
axs[1, 0].legend()
# Coumn 3
axs[2, 0].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2, 0].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2, 0].set_xticks(range(len(data3)))
axs[2, 0].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2, 0].set_title('\nDataset size: 1300 MB',fontsize=15)
axs[2, 0].legend()

# 2 cores & 6 instances - 4W
# 2 cores & 12 instances
data1 = df[(df['Cores & Instances'] == '2 cores & 6 instances - 4W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 6 instances - 4W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 6 instances - 4W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0, 1].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0, 1].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0, 1].set_xticks([])
axs[0, 1].set_title(r'$\bf{4\ workers}$' + '\n\nDataset size: 100 MB',fontsize=15)
axs[0, 1].legend()
# Column 2
axs[1, 1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1, 1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1, 1].set_xticks([])
axs[1, 1].set_title('\nDataset size: 700 MB', fontsize=15)
axs[1, 1].legend()
# Column 3
axs[2, 1].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2, 1].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2, 1].set_xticks(range(len(data3)))
axs[2, 1].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2, 1].set_title('\nDataset size: 1300 MB',fontsize=15)
axs[2, 1].legend()
fig.suptitle('Performance metrics with 2 Cores & 6 Instances', fontsize=25,fontweight="bold")

# 2nd test #
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(40, 15))
# 2 cores & 12 instances - 2W
data1 = df[(df['Cores & Instances'] == '2 cores & 12 instances') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 12 instances') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 12 instances') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0, 0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0, 0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0, 0].set_xticks([])
axs[0, 0].set_title(r'$\bf{2\ workers}$' +'\n\nDataset size: 100 MB',fontsize=15)
axs[0, 0].legend()
# Column 2
axs[1, 0].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1, 0].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1, 0].set_xticks([])
axs[1, 0].set_title('\nDataset size: 700 MB', fontsize=15)
axs[1, 0].legend()
# Coumn 3
axs[2, 0].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2, 0].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2, 0].set_xticks(range(len(data3)))
axs[2, 0].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2, 0].set_title('\nDataset size: 1300 MB',fontsize=15)
axs[2, 0].legend()

# 2 cores & 12 instances - 4W
data1 = df[(df['Cores & Instances'] == '2 cores & 12 instances - 4W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 12 instances - 4W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 12 instances - 4W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0, 1].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0, 1].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0, 1].set_xticks([])
axs[0, 1].set_title(r'$\bf{4\ workers}$' + '\n\nDataset size: 100 MB',fontsize=15)
axs[0, 1].legend()
# Column 2
axs[1, 1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1, 1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1, 1].set_xticks([])
axs[1, 1].set_title('\nDataset size: 700 MB', fontsize=15)
axs[1, 1].legend()
# Column 3
axs[2, 1].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2, 1].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2, 1].set_xticks(range(len(data3)))
axs[2, 1].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2, 1].set_title('\nDataset size: 1300 MB',fontsize=15)
axs[2, 1].legend()
fig.suptitle('Performance metrics with 2 Cores & 12 Instances', fontsize=25,fontweight="bold")

# 3rd test #
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(40, 15))
# 2 cores & 18 instances - 4W
data1 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 2W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 2W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 2W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0, 0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0, 0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0, 0].set_xticks([])
axs[0, 0].set_title(r'$\bf{2\ workers}$' +'\n\nDataset size: 100 MB',fontsize=15)
axs[0, 0].legend()
# Column 2
axs[1, 0].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1, 0].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1, 0].set_xticks([])
axs[1, 0].set_title('\nDataset size: 700 MB', fontsize=15)
axs[1, 0].legend()
# Coumn 3
axs[2, 0].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2, 0].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2, 0].set_xticks(range(len(data3)))
axs[2, 0].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2, 0].set_title('\nDataset size: 1300 MB',fontsize=15)
axs[2, 0].legend()

# 2 cores & 18 instances - 4W
data1 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 4W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 4W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 4W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0, 1].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0, 1].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0, 1].set_xticks([])
axs[0, 1].set_title(r'$\bf{4\ workers}$' + '\n\nDataset size: 100 MB',fontsize=15)
axs[0, 1].legend()
# Column 2
axs[1, 1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1, 1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1, 1].set_xticks([])
axs[1, 1].set_title('\nDataset size: 700 MB', fontsize=15)
axs[1, 1].legend()
# Column 3
axs[2, 1].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2, 1].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2, 1].set_xticks(range(len(data3)))
axs[2, 1].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2, 1].set_title('\nDataset size: 1300 MB',fontsize=15)
axs[2, 1].legend()
fig.suptitle('Performance metrics with 2 Cores & 18 Instances', fontsize=25,fontweight="bold")


# 4th test #
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(40, 15))
# 2 cores & 24 instances - 2W
data1 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 2W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 2W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 2W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0, 0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0, 0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0, 0].set_xticks([])
axs[0, 0].set_title(r'$\bf{2\ workers}$' +'\n\nDataset size: 100 MB',fontsize=15)
axs[0, 0].legend()
# Column 2
axs[1, 0].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1, 0].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1, 0].set_xticks([])
axs[1, 0].set_title('\nDataset size: 700 MB', fontsize=15)
axs[1, 0].legend()
# Coumn 3
axs[2, 0].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2, 0].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2, 0].set_xticks(range(len(data3)))
axs[2, 0].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2, 0].set_title('\nDataset size: 1300 MB',fontsize=15)
axs[2, 0].legend()

# 2 cores & 24 instances - 4W
data1 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 4W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 4W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 4W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0, 1].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0, 1].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0, 1].set_xticks([])
axs[0, 1].set_title(r'$\bf{4\ workers}$' + '\n\nDataset size: 100 MB',fontsize=15)
axs[0, 1].legend()
# Column 2
axs[1, 1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1, 1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1, 1].set_xticks([])
axs[1, 1].set_title('\nDataset size: 700 MB', fontsize=15)
axs[1, 1].legend()
# Column 3
axs[2, 1].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2, 1].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2, 1].set_xticks(range(len(data3)))
axs[2, 1].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2, 1].set_title('\nDataset size: 1300 MB',fontsize=15)
axs[2, 1].legend()
fig.suptitle('Performance metrics with 2 Cores & 24 Instances', fontsize=25,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Performance metrics with 2 Cores & 24 Instances')

# %%
# 2 cores & 6 instances
# Create subplots
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(40, 15))
data1 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0, 0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0, 0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0, 0].set_xticks([])
axs[0, 0].set_title(r'$\bf{2\ cores\ and\ 6\ instances}$' +'\n\nDataset size: 100 MB',fontsize=15)
axs[0, 0].legend()
# Column 2
axs[1, 0].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1, 0].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1, 0].set_xticks([])
axs[1, 0].set_title('\nDataset size: 700 MB', fontsize=15)
axs[1, 0].legend()
# Coumn 3
axs[2, 0].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2, 0].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2, 0].set_xticks(range(len(data3)))
axs[2, 0].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2, 0].legend()
# 2 cores & 12 instances
data1 = df[(df['Cores & Instances'] == '2 cores & 12 instances') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 12 instances') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 12 instances') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0, 1].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0, 1].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0, 1].set_xticks([])
axs[0, 1].set_title(r'$\bf{2\ cores\ and\ 12\ instances}$' + '\n\nDataset size: 100 MB',fontsize=15)
axs[0, 1].legend()
# Column 2
axs[1, 1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1, 1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1, 1].set_xticks([])
axs[1, 1].set_title('\nDataset size: 700 MB', fontsize=15)
axs[1, 1].legend()
# Column 3
axs[2, 1].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2, 1].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2, 1].set_xticks(range(len(data3)))
axs[2, 1].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2, 1].set_title('\nDataset size: 1300 MB',fontsize=15)
axs[2, 1].legend()
# 2 cores & 18 instances
data1 = df[(df['Cores & Instances'] == '2 cores & 18 instances') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 18 instances') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 18 instances') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0, 2].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0, 2].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0, 2].set_xticks(range(len(data1)))
axs[0, 2].set_xticklabels(data1['Query/Model'].values, rotation=45)
axs[0, 2].set_title(r'$\bf{2\ cores\ and\ 18\ instances}$' + '\n\nDataset size: 100 MB',fontsize=15)
axs[0, 2].legend()
# Column 2
axs[1, 2].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1, 2].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1, 2].set_xticks(range(len(data2)))
axs[1, 2].set_xticklabels(data2['Query/Model'].values, rotation=45)
axs[1, 2].set_title('\nDataset size: 700 MB', fontsize=15)
axs[1, 2].legend()
# Column 3
axs[2, 2].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2, 2].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2, 2].set_xticks(range(len(data3)))
axs[2, 2].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2, 2].set_title('\nDataset size: 1300 MB')
axs[2, 2].legend()
fig.suptitle('Performance metrics for different Cores Instances configurations', fontsize=25,fontweight="bold")
for ax in axs.flat:
     ax.label_outer()
#fig.tight_layout()

# %% [markdown]
# ## 2 cores & 6 Instances - 2 workers

# %%
# 2 cores & 6 instances
# Create subplots
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(20, 10))
data1 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 6 instances') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0].set_xticks([])
axs[0].set_title('Dataset size: 100 MB',fontsize=15)
axs[0].legend()
# Column 2
axs[1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1].set_xticks([])
axs[1].set_title('Dataset size: 700 MB', fontsize=15)
axs[1].legend()
# Coumn 3
axs[2].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2].set_xticks(range(len(data3)))
axs[2].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2].set_title('Dataset size: 1300 MB', fontsize=15)
axs[2].legend()
fig.suptitle('Performance metrics with 2 Cores & 6 Instances - 2 Workers', fontsize=25,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Performance metrics with 2 Cores & 6 Instances - 2 Workers')

# %% [markdown]
# ## 2 cores & 6 instances - 4 workers

# %%
# 2 cores & 6 instances
# Create subplots
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(20, 10))
data1 = df[(df['Cores & Instances'] == '2 cores & 6 instances - 4W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 6 instances - 4W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 6 instances - 4W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0].set_xticks([])
axs[0].set_title('Dataset size: 100 MB',fontsize=15)
axs[0].legend()
# Column 2
axs[1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1].set_xticks([])
axs[1].set_title('Dataset size: 700 MB', fontsize=15)
axs[1].legend()
# Coumn 3
axs[2].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2].set_xticks(range(len(data3)))
axs[2].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2].set_title('Dataset size: 1300 MB', fontsize=15)
axs[2].legend()
fig.suptitle('Performance metrics with 2 Cores & 6 Instances - 4 Workers', fontsize=25,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Performance metrics with 2 Cores & 6 Instances - 4 Workers')

# %% [markdown]
# ## 2 Cores & 12 Instances - 2 workers

# %%
# 2 cores & 12 instances
# Create subplots
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(20, 10))
data1 = df[(df['Cores & Instances'] == '2 cores & 12 instances') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 12 instances') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 12 instances') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0].set_xticks([])
axs[0].set_title('Dataset size: 100 MB',fontsize=15)
axs[0].legend()
# Column 2
axs[1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1].set_xticks([])
axs[1].set_title('Dataset size: 700 MB', fontsize=15)
axs[1].legend()
# Coumn 3
axs[2].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2].set_xticks(range(len(data3)))
axs[2].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2].set_title('Dataset size: 1300 MB', fontsize=15)
axs[2].legend()
fig.suptitle('Performance metrics with 2 Cores & 12 Instances - 2 Workers', fontsize=25,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Performance metrics with 2 Cores & 12 Instances - 2 Workers')

# %% [markdown]
# ## 2 cores & 12 instances - 4 workers

# %%
# 2 cores & 12 instances
# Create subplots
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(20, 10))
data1 = df[(df['Cores & Instances'] == '2 cores & 12 instances - 4W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 12 instances - 4W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 12 instances - 4W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0].set_xticks([])
axs[0].set_title('Dataset size: 100 MB',fontsize=15)
axs[0].legend()
# Column 2
axs[1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1].set_xticks([])
axs[1].set_title('Dataset size: 700 MB', fontsize=15)
axs[1].legend()
# Coumn 3
axs[2].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2].set_xticks(range(len(data3)))
axs[2].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2].set_title('Dataset size: 1300 MB', fontsize=15)
axs[2].legend()
fig.suptitle('Performance metrics with 2 Cores & 12 Instances -  4 Workers', fontsize=25,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Performance metrics with 2 Cores & 12 Instances -  4 Workers')

# %% [markdown]
# ## 2 Cores & 18 Instances - 2 Workers

# %%
# 2 cores & 18 instances
# Create subplots
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(20, 10))
data1 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 2W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 2W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 2W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0].set_xticks([])
axs[0].set_title('Dataset size: 100 MB',fontsize=15)
axs[0].legend()
# Column 2
axs[1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1].set_xticks([])
axs[1].set_title('Dataset size: 700 MB', fontsize=15)
axs[1].legend()
# Coumn 3
axs[2].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2].set_xticks(range(len(data3)))
axs[2].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2].set_title('Dataset size: 1300 MB', fontsize=15)
axs[2].legend()
fig.suptitle('Performance metrics with 2 Cores & 18 Instances - 2 Workers', fontsize=25,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Performance metrics with 2 Cores & 18 Instances - 2 Workers')

# %% [markdown]
# ## 2 Cores & 18 Instances - 4 Workers

# %%
# 2 cores & 18 instances - 4W
# Create subplots
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(20, 10))
data1 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 4W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 4W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 18 instances - 4W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0].set_xticks([])
axs[0].set_title('Dataset size: 100 MB',fontsize=15)
axs[0].legend()
# Column 2
axs[1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1].set_xticks([])
axs[1].set_title('Dataset size: 700 MB', fontsize=15)
axs[1].legend()
# Coumn 3
axs[2].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2].set_xticks(range(len(data3)))
axs[2].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2].set_title('Dataset size: 1300 MB', fontsize=15)
axs[2].legend()
fig.suptitle('Performance metrics with 2 Cores & 18 Instances - 4 Workers', fontsize=25,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Performance metrics with 2 Cores & 18 Instances - 4 Workers')

# %% [markdown]
# ## 2 Cores & 24 Instances - 2 Workers

# %%
# 2 cores & 24 instances - 2W
# Create subplots
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(20, 10))
data1 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 2W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 2W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 2W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0].set_xticks([])
axs[0].set_title('Dataset size: 100 MB',fontsize=15)
axs[0].legend()
# Column 2
axs[1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1].set_xticks([])
axs[1].set_title('Dataset size: 700 MB', fontsize=15)
axs[1].legend()
# Coumn 3
axs[2].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2].set_xticks(range(len(data3)))
axs[2].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2].set_title('Dataset size: 1300 MB', fontsize=15)
axs[2].legend()
fig.suptitle('Performance metrics with 2 Cores & 24 Instances - 2 Workers', fontsize=25,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Performance metrics with 2 Cores & 24 Instances - 2 Workers')

# %% [markdown]
# ## 2 Cores & 24 Instances - 4 Workers

# %%
# 2 cores & 24 instances - 2W
# Create subplots
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(20, 10))
data1 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 4W') & (df['Dataset size'] == 100)].reset_index(drop=True)
data1['Model_label'] = pd.factorize(data1['Query/Model'])[0]
data2 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 4W') & (df['Dataset size'] == 700)].reset_index(drop=True)
data2['Model_label'] = pd.factorize(data2['Query/Model'])[0]
data3 = df[(df['Cores & Instances'] == '2 cores & 24 instances - 4W') & (df['Dataset size'] == 1300)].reset_index(drop=True)
data3['Model_label'] = pd.factorize(data3['Query/Model'])[0]
# Column 1
axs[0].bar(data1['Model_label'], data1['Execution Time'],width=0.25, label='Execution Time')
axs[0].bar(data1['Model_label']+0.25, data1['CPU Usage'],width=0.25, label='CPU Usage')
axs[0].set_xticks([])
axs[0].set_title('Dataset size: 100 MB',fontsize=15)
axs[0].legend()
# Column 2
axs[1].bar(data2['Model_label'], data2['Execution Time'],width=0.25, label='Execution Time')
axs[1].bar(data2['Model_label']+0.25, data2['CPU Usage'],width=0.25, label='CPU Usage')
axs[1].set_xticks([])
axs[1].set_title('Dataset size: 700 MB', fontsize=15)
axs[1].legend()
# Coumn 3
axs[2].bar(data3['Model_label'], data3['Execution Time'],width=0.25, label='Execution Time')
axs[2].bar(data3['Model_label']+0.25, data3['CPU Usage'],width=0.25, label='CPU Usage')
axs[2].set_xticks(range(len(data3)))
axs[2].set_xticklabels(data3['Query/Model'].values, rotation=45)
axs[2].set_title('Dataset size: 1300 MB', fontsize=15)
axs[2].legend()
fig.suptitle('Performance metrics with 2 Cores & 24 Instances - 4 Workers', fontsize=25,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Performance metrics with 2 Cores & 24 Instances - 4 Workers')
